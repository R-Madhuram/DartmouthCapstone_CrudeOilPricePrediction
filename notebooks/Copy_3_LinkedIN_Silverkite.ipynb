# %% [markdown]
# <a href="https://colab.research.google.com/github/R-Madhuram/DartmouthCapstone_CrudeOilPricePrediction/blob/main/Copy_3_LinkedIN_Silverkite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LinkedIn SilverKite

# %% [markdown]
# LinkedIN Silverkite is a forecasting library. We can Use various ML agirthms in this as well. In this notebook we would be exploring ridge regression and Gradient boosting algorithmic fit.
#
# Although many more fit algorithms could be testes since this is an exploratory study of various ML tools available to predict the sales of crude oil based on histoprical data, we limit our selves to testing only teo fit methods in this study .

# %% [markdown]
# # Libraries

# %%
# Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Change directory
# %cd /content/drive/MyDrive/Time Series Forecasting Product
# Out:
# /content/drive/MyDrive/Time Series Forecasting Product

# %%
#Install Greykite
# !pip install greykite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting greykite
#   Downloading greykite-0.4.0-py2.py3-none-any.whl (22.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.12.0 in /usr/local/lib/python3.9/dist-packages (from greykite) (5.13.1)
# Collecting holidays-ext>=0.0.7
#   Downloading holidays_ext-0.0.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.9/dist-packages (from greykite) (1.2.2)
# Collecting osqp==0.6.1
#   Downloading osqp-0.6.1.tar.gz (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 kB 28.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytest>=4.6.5 in /usr/local/lib/python3.9/dist-packages (from greykite) (7.2.2)
# Collecting dill>=0.3.3
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.4.1 in /usr/local/lib/python3.9/dist-packages (from greykite) (3.7.1)
# Requirement already satisfied: cvxpy>=1.1.12 in /usr/local/lib/python3.9/dist-packages (from greykite) (1.3.1)
# Collecting pytest-runner>=5.1
#   Downloading pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Collecting overrides>=2.8.0
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.9/dist-packages (from greykite) (1.10.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from greykite) (0.5.3)
# Requirement already satisfied: numpy>=1.19.2 in /usr/local/lib/python3.9/dist-packages (from greykite) (1.22.4)
# Collecting testfixtures>=6.14.2
#   Downloading testfixtures-7.1.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from greykite) (1.16.0)
# Collecting pandas<1.3,>=1.1.3
#   Downloading pandas-1.2.5-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 82.3 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.12.2 in /usr/local/lib/python3.9/dist-packages (from greykite) (0.13.5)
# Requirement already satisfied: tqdm>=4.52.0 in /usr/local/lib/python3.9/dist-packages (from greykite) (4.65.0)
# Collecting pmdarima>=1.8.0
#   Downloading pmdarima-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 84.3 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from osqp==0.6.1->greykite) (0.18.3)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.9/dist-packages (from cvxpy>=1.1.12->greykite) (67.6.1)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.9/dist-packages (from cvxpy>=1.1.12->greykite) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.9/dist-packages (from cvxpy>=1.1.12->greykite) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from holidays-ext>=0.0.7->greykite) (2.8.2)
# Collecting LunarCalendar-ext>=0.0.1
#   Downloading LunarCalendar_ext-0.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.9/dist-packages (from holidays-ext>=0.0.7->greykite) (2.4.0)
# Requirement already satisfied: holidays>=0.9.5 in /usr/local/lib/python3.9/dist-packages (from holidays-ext>=0.0.7->greykite) (0.22)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4.1->greykite) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas<1.3,>=1.1.3->greykite) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.12.0->greykite) (8.2.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima>=1.8.0->greykite) (1.26.15)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from pmdarima>=1.8.0->greykite) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima>=1.8.0->greykite) (0.29.34)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest>=4.6.5->greykite) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest>=4.6.5->greykite) (22.2.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest>=4.6.5->greykite) (2.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest>=4.6.5->greykite) (2.0.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest>=4.6.5->greykite) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.24.1->greykite) (3.1.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.9/dist-packages (from convertdate>=2.1.2->holidays-ext>=0.0.7->greykite) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.9/dist-packages (from holidays>=0.9.5->holidays-ext>=0.0.7->greykite) (0.3.1)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.9/dist-packages (from holidays>=0.9.5->holidays-ext>=0.0.7->greykite) (2.2.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.4.1->greykite) (3.15.0)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.9/dist-packages (from LunarCalendar-ext>=0.0.1->holidays-ext>=0.0.7->greykite) (4.1.4)
# Building wheels for collected packages: osqp
#   Building wheel for osqp (setup.py) ... done
#   Created wheel for osqp: filename=osqp-0.6.1-cp39-cp39-linux_x86_64.whl size=209938 sha256=50568b6e00572058bc6b79839915b92715a3aa3d94cbc7512bf38808c738f4d5
#   Stored in directory: /root/.cache/pip/wheels/3d/34/b7/b8b2af435e6e6d4ce9c92611064e6c8589579bbf4148ea4d50
# Successfully built osqp
# Installing collected packages: testfixtures, pytest-runner, overrides, dill, pandas, osqp, LunarCalendar-ext, holidays-ext, pmdarima, greykite
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: osqp
#     Found existing installation: osqp 0.6.2.post0
#     Uninstalling osqp-0.6.2.post0:
#       Successfully uninstalled osqp-0.6.2.post0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.17 requires pandas>=1.3.0, but you have pandas 1.2.5 which is incompatible.
# xarray 2022.12.0 requires pandas>=1.3, but you have pandas 1.2.5 which is incompatible.
# plotnine 0.10.1 requires pandas>=1.3.5, but you have pandas 1.2.5 which is incompatible.
# mizani 0.8.1 requires pandas>=1.3.5, but you have pandas 1.2.5 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 1.2.5 which is incompatible.
# arviz 0.15.1 requires pandas>=1.3.0, but you have pandas 1.2.5 which is incompatible.
# Successfully installed LunarCalendar-ext-0.0.1 dill-0.3.6 greykite-0.4.0 holidays-ext-0.0.8 osqp-0.6.1 overrides-7.3.1 pandas-1.2.5 pmdarima-2.0.3 pytest-runner-6.0.0 testfixtures-7.1.0

# %%
#Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from greykite.framework.templates.autogen.forecast_config import *
from greykite.framework.templates.forecaster import Forecaster
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.common.features.timeseries_features import *
from greykite.common.evaluation import EvaluationMetricEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
from plotly.offline import iplot

# %% [markdown]
# # Load Data

# %%
# load data
us_cushing = pd.read_csv('/content/drive/MyDrive/PCDS_OilPricePrediction/data/USCushing.csv')
eu_brent = pd.read_csv('/content/drive/MyDrive/PCDS_OilPricePrediction/data/EuropeanBrent.csv')

# %% [markdown]
# # 1_Modeling with LinkedIn Silverkite

# %% [markdown]
# ## Cushing Data

# %%
# Read data 
us_cushing.head().append(us_cushing.tail())
# Out:
#               Date  Cushing, OK WTI Spot Price FOB (Dollars per Barrel)
# 0     Jan 02, 1986                                              25.56
# 1     Jan 03, 1986                                              26.00
# 2     Jan 06, 1986                                              26.53
# 3     Jan 07, 1986                                              25.85
# 4     Jan 08, 1986                                              25.87
# 9357  Feb 22, 2023                                              73.95
# 9358  Feb 23, 2023                                              75.26
# 9359  Feb 24, 2023                                              76.19
# 9360  Feb 27, 2023                                              75.57
# 9361           NaN                                                NaN

# %%
# Renaming columns
df_cushing_fp = us_cushing.rename(columns = {'Cushing, OK WTI Spot Price FOB (Dollars per Barrel)':'y'})
df_cushing_fp.head(3).append(df_cushing_fp.tail(3))
# Out:
#               Date      y
# 0     Jan 02, 1986  25.56
# 1     Jan 03, 1986  26.00
# 2     Jan 06, 1986  26.53
# 9359  Feb 24, 2023  76.19
# 9360  Feb 27, 2023  75.57
# 9361           NaN    NaN

# %% [markdown]
# ### Silverkite Preparations

# %%
# Specifying time series names/variables
"""Here we specify the date column,y column, the frequency 
and until when is training data. It specifies the skeleton of the data."""

metadata = MetadataParam(time_col = 'Date',
                         value_col='y',
                         freq = 'B',
                         train_end_date = pd.to_datetime('2023-2-27'))
metadata
# Out:
# MetadataParam(anomaly_info=None, date_format=None, freq='B', time_col='Date', train_end_date=Timestamp('2023-02-27 00:00:00'), value_col='y')

# %%
# Growth term possibilities
"""Silverkite and all other models till now we built can work with dictionaries"""
"""we can specify everything step by step but it is prone to spelling mistakes"""
growth = dict(growth_term = ['linear'])
print(growth)
print(type(growth))
# Out:
# {'growth_term': ['linear']}
# <class 'dict'>

# %%
# seasonality term possibilities
""" In sarimax we had only one seasonality, in prophet we had 3 seasonality namely
daily, weekly and yearly and we could have all of them. Assuming we have hourly data
we can have upto 5 seasonalities"""
"""yearly_seasonality and rest all can be set to :none,true,auto"""

seasonality = dict(yearly_seasonality = 'auto',
                   monthly_seasonality = 'auto',
                   weekly_seasonality = 'auto')
print(seasonality)
print(type(seasonality))
# Out:
# {'yearly_seasonality': 'auto', 'monthly_seasonality': 'auto', 'weekly_seasonality': 'auto'}
# <class 'dict'>

# %%
# Changepoints --> reflects changes in trends
changepoints = dict(changepoints_dict = dict(method = 'auto'))

# %%
# Auto Regression --> dependednt on the forecasting horizon
autoregression = dict(autoreg_dict = 'auto')
autoregression
# Out:
# {'autoreg_dict': 'auto'}

# %% [markdown]
# Silverkite offers the wrapper or fitting algorithms strategy that takes in to account all the possibilities that we have created and combines them.
#
# Linear regression, elastic net, ridge, lasso, stochastic gradient decent, lars, lasso lars, random forest, gradient boosting are some of the algorithm fitting possibilities.
#
# LR is poor with collinearity, stochastic gradient decent is unstable, lars is sensitive to outliers or noise, random forest and gradient boosting i.e tree models do not model the trend well.
#
# We will try Linear regression, Ridge regression, Random forest and gradient boosting.
#
# Ridge regression aims to decrease overfittign and not to have independent variables with too high importance/relevance.

# %%
# Custom fit Algorithm
custom = dict(fit_algorithm_dict = [dict(fit_algorithm = 'gradient_boosting'),
                                    dict(fit_algorithm = 'ridge')])

# %% [markdown]
# ### 1) Silverkite Model

# %%
#Build the model
model_components = ModelComponentsParam(growth = growth,
                                        seasonality = seasonality,
                                        changepoints = changepoints,
                                        autoregression = autoregression,
                                        custom = custom)

# %%
#Cross-validation
evaluation_period = EvaluationPeriodParam(cv_min_train_periods= 506,
                                          cv_expanding_window = False,
                                          cv_max_splits = None,
                                          cv_periods_between_splits = 22,
                                          cv_horizon = 22)

# %%
#Evaluation metric 
evaluation_metric = EvaluationMetricParam(
    cv_selection_metric = EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
#Configuration
config = ForecastConfig(model_template = ModelTemplateEnum.SILVERKITE.name,
                        forecast_horizon = 289,
                        metadata_param = metadata,
                        model_components_param = model_components,
                        evaluation_period_param=evaluation_period,
                        evaluation_metric_param = evaluation_metric)

# %% [markdown]
# ## Brent Data

# %%
# Read data 
eu_brent.head().append(eu_brent.tail())
# Out:
#               Date  Europe Brent Spot Price FOB (Dollars per Barrel)
# 0     May 20, 1987                                             18.63
# 1     May 21, 1987                                             18.45
# 2     May 22, 1987                                             18.55
# 3     May 25, 1987                                             18.60
# 4     May 26, 1987                                             18.63
# 9077  Feb 22, 2023                                             79.55
# 9078  Feb 23, 2023                                             82.08
# 9079  Feb 24, 2023                                             82.31
# 9080  Feb 27, 2023                                             82.31
# 9081           NaN                                               NaN

# %%
# Renaming columns
eu_brent_fp = eu_brent.rename(columns = {'Europe Brent Spot Price FOB (Dollars per Barrel)':'y'})
eu_brent_fp.head(3).append(eu_brent_fp.tail(3))
# Out:
#               Date      y
# 0     May 20, 1987  18.63
# 1     May 21, 1987  18.45
# 2     May 22, 1987  18.55
# 9079  Feb 24, 2023  82.31
# 9080  Feb 27, 2023  82.31
# 9081           NaN    NaN

# %% [markdown]
# ### Silverkite Preparations

# %%
# Specifying time series names/variables
"""Here we specify the date column,y column, the frequency 
and until when is training data. It specifies the skeleton of the data."""

metadata_brent = MetadataParam(time_col = 'Date',
                         value_col='y',
                         freq = 'B',
                         train_end_date = pd.to_datetime('2023-2-27'))
metadata_brent
# Out:
# MetadataParam(anomaly_info=None, date_format=None, freq='B', time_col='Date', train_end_date=Timestamp('2023-02-27 00:00:00'), value_col='y')

# %%
# Growth term possibilities
"""Silverkite and all other models till now we built can work with dictionaries"""
"""we can specify everything step by step but it is prone to spelling mistakes"""
growth_brent = dict(growth_term = ['linear'])
print(growth)
print(type(growth))
# Out:
# {'growth_term': ['linear']}
# <class 'dict'>

# %%
# seasonality term possibilities
""" In sarimax we had only one seasonality, in prophet we had 3 seasonality namely
daily, weekly and yearly and we could have all of them. Assuming we have hourly data
we can have upto 5 seasonalities"""
"""yearly_seasonality and rest all can be set to :none,true,auto"""

seasonality_brent = dict(yearly_seasonality = 'auto',
                   monthly_seasonality = 'auto',
                   weekly_seasonality = 'auto')
print(seasonality_brent)
print(type(seasonality_brent))
# Out:
# {'yearly_seasonality': 'auto', 'monthly_seasonality': 'auto', 'weekly_seasonality': 'auto'}
# <class 'dict'>

# %%
# Changepoints --> reflects changes in trends
changepoints_brent = dict(changepoints_dict = dict(method = 'auto'))

# %%
# Auto Regression --> dependednt on the forecasting horizon
autoregression_brent = dict(autoreg_dict = 'auto')
autoregression
# Out:
# {'autoreg_dict': 'auto'}

# %% [markdown]
# ### 1) Silverkite Model

# %%
# Custom fit Algorithm
custom_brent = dict(fit_algorithm_dict = [dict(fit_algorithm = 'gradient_boosting'),
                                    dict(fit_algorithm = 'ridge')])

# %%
#Build the model
model_components_brent = ModelComponentsParam(growth = growth_brent,
                                        seasonality = seasonality_brent,
                                        changepoints = changepoints_brent,
                                        autoregression = autoregression_brent,
                                        custom = custom_brent)

# %%
#Cross-validation
evaluation_period_brent = EvaluationPeriodParam(cv_min_train_periods= 506,
                                          cv_expanding_window = False,
                                          cv_max_splits = None,
                                          cv_periods_between_splits = 22,
                                          cv_horizon = 22)

# %%
#Evaluation metric 
evaluation_metric_brent = EvaluationMetricParam(
    cv_selection_metric = EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
#Configuration
config_brent = ForecastConfig(model_template = ModelTemplateEnum.SILVERKITE.name,
                        forecast_horizon = 289,
                        metadata_param = metadata_brent,
                        model_components_param = model_components_brent,
                        evaluation_period_param=evaluation_period_brent,
                        evaluation_metric_param = evaluation_metric_brent)

# %% [markdown]
# # 2_Forecasting

# %% [markdown]
# ## Cushing Data

# %% [markdown]
# ### 1) Silverkite Model

# %%
#Forecasting
forecaster = Forecaster()
result = forecaster.run_forecast_config(df = df_cushing_fp,
                                        config = config)
# Out:
# /usr/local/lib/python3.9/dist-packages/greykite/common/time_properties.py:197: UserWarning:
#
# Dropped 1 dates when filling gaps in input data. Provide data frequency and make sure data points are evenly spaced.
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 18 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 321 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 332 value(s) in y_true were NA or infinite and are omitted in error calc.

# %%
#Look at the model summary
summary = result.model[-1].summary() #-1 restrieves the estimator from the pipeline
print(summary)
# Out:
# ================================ Model Summary =================================
#
# Number of observations: 9693,   Number of features: 230
# Method: Gradient Boosting
# Number of Trees: 100,   Criterion: FRIEDMAN_MSE
# Subsample: 1.0,   Max features: 230,   Max depth: 3
#
# Residuals:
#          Min           1Q       Median           3Q          Max
#       -60.91       -1.597      -0.1425        1.388        21.06
#
#             Pred_col Feature importance  Importance rank
#            Intercept                 0.              230
#  events_C...New Year                 0.               94
#  events_C...w Year-1                 0.               93
#  events_C...w Year-2                 0.               92
#  events_C...w Year+1                 0.               91
#  events_C...w Year+2                 0.               90
# events_Christmas Day                 0.               89
#  events_C...as Day-1                 0.               88
#  events_C...as Day-2                 0.               87
#  events_C...as Day+1                 0.               86
#  events_C...as Day+2                 0.               85
#  events_E...Ireland]                 0.               84
#  events_E...eland]-1                 0.               82
#  events_E...eland]-2                 0.               70
#  events_E...eland]+1                 0.               81
#  events_E...eland]+2                 0.               80
#   events_Good Friday                 0.               79
# events_Good Friday-1                 0.               78
# events_Good Friday-2                 0.               77
# events_Good Friday+1                 0.               76
# events_Good Friday+2                 0.               75
#  events_I...ence Day                 0.               74
#  events_I...ce Day-1                 0.               73
#  events_I...ce Day-2                 0.               72
#  events_I...ce Day+1                 0.               71
#  events_I...ce Day+2                 0.               95
#     events_Labor Day                 0.               83
#   events_Labor Day-1                 0.               96
#   events_Labor Day-2                 0.              111
#   events_Labor Day+1                 0.              122
#   events_Labor Day+2                 0.              121
#  events_Memorial Day                 0.              120
#  events_M...al Day-1                 0.              119
#  events_M...al Day-2                 0.              118
#  events_M...al Day+1                 0.              117
#  events_M...al Day+2                 0.              116
# events_New Years Day                 0.              115
#  events_N...rs Day-1                 0.              114
#  events_N...rs Day-2                 0.              113
#  events_N...rs Day+1                 0.              112
#  events_N...rs Day+2                 0.              110
#         events_Other                 0.               98
#       events_Other-1                 0.              109
#       events_Other-2                 0.              108
#       events_Other+1                 0.              107
#       events_Other+2                 0.              106
#  events_Thanksgiving                 0.              105
#  events_T...giving-1                 0.              104
#  events_T...giving-2                 0.               68
#  events_T...giving+1                 0.              102
#  events_T...giving+2                 0.              101
#  events_Veterans Day                 0.              100
#  events_V...ns Day-1                 0.               99
#  events_V...ns Day-2                 0.               97
#  events_V...ns Day+1                 0.               69
#  events_V...ns Day+2                 0.               61
#        str_dow_2-Tue                 0.               67
#        str_dow_3-Wed                 0.               28
#        str_dow_4-Thu                 0.               29
#        str_dow_5-Fri                 0.               26
#        str_dow_6-Sat                 0.               34
#        str_dow_7-Sun                 0.               38
#                  ct1            0.06337                5
#       is_weekend:ct1                 0.               39
#    str_dow_2-Tue:ct1                 0.               40
#    str_dow_3-Wed:ct1                 0.               41
#    str_dow_4-Thu:ct1                 0.               42
#    str_dow_5-Fri:ct1                 0.               36
#    str_dow_6-Sat:ct1                 0.               25
#    str_dow_7-Sun:ct1                 0.               37
#    cp0_1990_10_15_00             0.1691                3
#  is_weeke...10_15_00                 0.               35
#  str_dow_...10_15_00                 0.               33
#  str_dow_...10_15_00                 0.               32
#  str_dow_...10_15_00                 0.               31
#  str_dow_...10_15_00                 0.               30
#  str_dow_...10_15_00                 0.               27
#  str_dow_...10_15_00                 0.               43
#    cp1_1997_05_29_00            0.05011                7
#  is_weeke...05_29_00                 0.               45
#  str_dow_...05_29_00                 0.               57
#  str_dow_...05_29_00                 0.               66
#  str_dow_...05_29_00                 0.               65
#  str_dow_...05_29_00                 0.               64
#  str_dow_...05_29_00                 0.               63
#  str_dow_...05_29_00                 0.               62
#    cp2_1999_12_24_00             0.2914                1
#  is_weeke...12_24_00                 0.               44
#  str_dow_...12_24_00                 0.               60
#  str_dow_...12_24_00                 0.               59
#  str_dow_...12_24_00                 0.               58
#  str_dow_...12_24_00                 0.               56
#  str_dow_...12_24_00                 0.               46
#  str_dow_...12_24_00                 0.               55
#    cp3_2003_08_29_00             0.2676                2
#  is_weeke...08_29_00                 0.               54
#  str_dow_...08_29_00                 0.               53
#  str_dow_...08_29_00                 0.               52
#  str_dow_...08_29_00                 0.               51
#  str_dow_...08_29_00                 0.               50
#  str_dow_...08_29_00                 0.               49
#  str_dow_...08_29_00                 0.               48
#    cp4_2008_06_11_00            0.06359                4
#  is_weeke...06_11_00                 0.               47
#  str_dow_...06_11_00                 0.              123
#  str_dow_...06_11_00                 0.              103
#  str_dow_...06_11_00                 0.              125
#  str_dow_...06_11_00                 0.              152
#  str_dow_...06_11_00                 0.              203
#  str_dow_...06_11_00                 0.              202
#    cp5_2012_02_14_00            0.05115                6
#  is_weeke...02_14_00                 0.              201
#  str_dow_...02_14_00                 0.              200
#  str_dow_...02_14_00                 0.              199
#  str_dow_...02_14_00                 0.              124
#  str_dow_...02_14_00                 0.              198
#  str_dow_...02_14_00                 0.              197
#  str_dow_...02_14_00                 0.              196
#    cp6_2016_03_02_00             0.0111                9
#  is_weeke...03_02_00                 0.              195
#  str_dow_...03_02_00                 0.              194
#  str_dow_...03_02_00                 0.              193
#  str_dow_...03_02_00                 0.              192
#  str_dow_...03_02_00                 0.              191
#  str_dow_...03_02_00                 0.              190
#  str_dow_...03_02_00                 0.              189
#    cp7_2019_11_06_00            0.01985                8
#  is_weeke...11_06_00                 0.              188
#  str_dow_...11_06_00                 0.              187
#  str_dow_...11_06_00                 0.              186
#  str_dow_...11_06_00                 0.              185
#  str_dow_...11_06_00                 0.              184
#  str_dow_...11_06_00                 0.              183
#  str_dow_...11_06_00                 0.              182
#    cp8_2020_03_19_00           0.007547               10
#  is_weeke...03_19_00                 0.              181
#  str_dow_...03_19_00                 0.              204
#  str_dow_...03_19_00                 0.              205
#  str_dow_...03_19_00                 0.              206
#  str_dow_...03_19_00                 0.              219
#  str_dow_...03_19_00                 0.              229
#  str_dow_...03_19_00                 0.              228
#  ct1:sin1_tow_weekly                 0.              227
#  ct1:cos1_tow_weekly                 0.              226
#  ct1:sin2_tow_weekly                 0.              225
#  ct1:cos2_tow_weekly                 0.              224
#  cp0_1990...w_weekly                 0.              223
#  cp0_1990...w_weekly                 0.              222
#  cp0_1990...w_weekly                 0.              221
#  cp0_1990...w_weekly                 0.              220
#  cp1_1997...w_weekly                 0.              218
#  cp1_1997...w_weekly                 0.              207
#  cp1_1997...w_weekly                 0.              217
#  cp1_1997...w_weekly                 0.              216
#  cp2_1999...w_weekly                 0.              215
#  cp2_1999...w_weekly                 0.              214
#  cp2_1999...w_weekly                 0.              213
#  cp2_1999...w_weekly                 0.              212
#  cp3_2003...w_weekly                 0.              211
#  cp3_2003...w_weekly                 0.              210
#  cp3_2003...w_weekly                 0.              209
#  cp3_2003...w_weekly                 0.              208
#  cp4_2008...w_weekly                 0.              180
#  cp4_2008...w_weekly                 0.              179
#  cp4_2008...w_weekly                 0.              178
#  cp4_2008...w_weekly                 0.              177
#  cp5_2012...w_weekly                 0.              149
#  cp5_2012...w_weekly                 0.              148
#  cp5_2012...w_weekly                 0.              147
#  cp5_2012...w_weekly                 0.              146
#  cp6_2016...w_weekly                 0.              145
#  cp6_2016...w_weekly                 0.              144
#  cp6_2016...w_weekly                 0.              143
#  cp6_2016...w_weekly                 0.              142
#  cp7_2019...w_weekly                 0.              141
#  cp7_2019...w_weekly                 0.              140
#  cp7_2019...w_weekly                 0.              139
#  cp7_2019...w_weekly                 0.              138
#  cp8_2020...w_weekly                 0.              137
#  cp8_2020...w_weekly                 0.              136
#  cp8_2020...w_weekly                 0.              135
#  cp8_2020...w_weekly                 0.              134
#      sin1_tow_weekly                 0.              133
#      cos1_tow_weekly                 0.              132
#      sin2_tow_weekly                 0.              131
#      cos2_tow_weekly                 0.              130
#      sin3_tow_weekly                 0.              129
#      cos3_tow_weekly                 0.              128
#      sin4_tow_weekly                 0.              127
#      cos4_tow_weekly                 0.              150
#   sin1_toq_quarterly          6.305e-05               14
#   cos1_toq_quarterly                 0.              126
#   sin2_toq_quarterly                 0.              151
#   cos2_toq_quarterly                 0.              153
#   sin3_toq_quarterly                 0.              176
#   cos3_toq_quarterly                 0.              175
#   sin4_toq_quarterly                 0.              174
#   cos4_toq_quarterly                 0.              173
#   sin5_toq_quarterly                 0.              172
#   cos5_toq_quarterly                 0.              171
#      sin1_ct1_yearly           0.001432               12
#      cos1_ct1_yearly           0.003092               11
#      sin2_ct1_yearly          0.0004036               13
#      cos2_ct1_yearly          5.109e-05               15
#      sin3_ct1_yearly          2.601e-05               17
#      cos3_ct1_yearly          2.221e-05               18
#      sin4_ct1_yearly          5.038e-05               16
#      cos4_ct1_yearly          8.833e-06               21
#      sin5_ct1_yearly          1.519e-05               20
#      cos5_ct1_yearly                 0.              170
#      sin6_ct1_yearly                 0.              169
#      cos6_ct1_yearly                 0.              168
#      sin7_ct1_yearly                 0.              167
#      cos7_ct1_yearly          1.010e-06               24
#      sin8_ct1_yearly                 0.              166
#      cos8_ct1_yearly                 0.              165
#      sin9_ct1_yearly                 0.              164
#      cos9_ct1_yearly                 0.              163
#     sin10_ct1_yearly                 0.              162
#     cos10_ct1_yearly                 0.              161
#     sin11_ct1_yearly                 0.              160
#     cos11_ct1_yearly                 0.              159
#     sin12_ct1_yearly                 0.              158
#     cos12_ct1_yearly                 0.              157
#     sin13_ct1_yearly                 0.              156
#     cos13_ct1_yearly                 0.              155
#     sin14_ct1_yearly          1.600e-05               19
#     cos14_ct1_yearly                 0.              154
#     sin15_ct1_yearly          1.870e-06               23
#     cos15_ct1_yearly          8.342e-06               22
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names

# %%
#visualization
fig = result.forecast.plot_components()
iplot(fig)

# %%
#visualization
fig = result.backtest.plot()
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5805c642-6185-4cb3-8742-f04371ad1c70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5805c642-6185-4cb3-8742-f04371ad1c70")) {                    Plotly.newPlot(                        "5805c642-6185-4cb3-8742-f04371ad1c70",                        [{"line":{"color":"rgba(250, 43, 20, 0.7)"},"marker":{"color":"rgba(250, 43, 20, 0.7)","size":2.0},"mode":"lines+markers","name":"Actual","opacity":1.0,"x":["1986-01-02T00:00:00","1986-01-03T00:00:00","1986-01-06T00:00:00","1986-01-07T00:00:00","1986-01-08T00:00:00","1986-01-09T00:00:00","1986-01-10T00:00:00","1986-01-13T00:00:00","1986-01-14T00:00:00","1986-01-15T00:00:00","1986-01-16T00:00:00","1986-01-17T00:00:00","1986-01-20T00:00:00","1986-01-21T00:00:00","1986-01-22T00:00:00","1986-01-23T00:00:00","1986-01-24T00:00:00","1986-01-27T00:00:00","1986-01-28T00:00:00","1986-01-29T00:00:00","1986-01-30T00:00:00","1986-01-31T00:00:00","1986-02-03T00:00:00","1986-02-04T00:00:00","1986-02-05T00:00:00","1986-02-06T00:00:00","1986-02-07T00:00:00","1986-02-10T00:00:00","1986-02-11T00:00:00","1986-02-12T00:00:00","1986-02-13T00:00:00","1986-02-14T00:00:00","1986-02-17T00:00:00","1986-02-18T00:00:00","1986-02-19T00:00:00","1986-02-20T00:00:00","1986-02-21T00:00:00","1986-02-24T00:00:00","1986-02-25T00:00:00","1986-02-26T00:00:00","1986-02-27T00:00:00","1986-02-28T00:00:00","1986-03-03T00:00:00","1986-03-04T00:00:00","1986-03-05T00:00:00","1986-03-06T00:00:00","1986-03-07T00:00:00","1986-03-10T00:00:00","1986-03-11T00:00:00","1986-03-12T00:00:00","1986-03-13T00:00:00","1986-03-14T00:00:00","1986-03-17T00:00:00","1986-03-18T00:00:00","1986-03-19T00:00:00","1986-03-20T00:00:00","1986-03-21T00:00:00","1986-03-24T00:00:00","1986-03-25T00:00:00","1986-03-26T00:00:00","1986-03-27T00:00:00","1986-03-28T00:00:00","1986-03-31T00:00:00","1986-04-01T00:00:00","1986-04-02T00:00:00","1986-04-03T00:00:00","1986-04-04T00:00:00","1986-04-07T00:00:00","1986-04-08T00:00:00","1986-04-09T00:00:00","1986-04-10T00:00:00","1986-04-11T00:00:00","1986-04-14T00:00:00","1986-04-15T00:00:00","1986-04-16T00:00:00","1986-04-17T00:00:00","1986-04-18T00:00:00","1986-04-21T00:00:00","1986-04-22T00:00:00","1986-04-23T00:00:00","1986-04-24T00:00:00","1986-04-25T00:00:00","1986-04-28T00:00:00","1986-04-29T00:00:00","1986-04-30T00:00:00","1986-05-01T00:00:00","1986-05-02T00:00:00","1986-05-05T00:00:00","1986-05-06T00:00:00","1986-05-07T00:00:00","1986-05-08T00:00:00","1986-05-09T00:00:00","1986-05-12T00:00:00","1986-05-13T00:00:00","1986-05-14T00:00:00","1986-05-15T00:00:00","1986-05-16T00:00:00","1986-05-19T00:00:00","1986-05-20T00:00:00","1986-05-21T00:00:00","1986-05-22T00:00:00","1986-05-23T00:00:00","1986-05-26T00:00:00","1986-05-27T00:00:00","1986-05-28T00:00:00","1986-05-29T00:00:00","1986-05-30T00:00:00","1986-06-02T00:00:00","1986-06-03T00:00:00","1986-06-04T00:00:00","1986-06-05T00:00:00","1986-06-06T00:00:00","1986-06-09T00:00:00","1986-06-10T00:00:00","1986-06-11T00:00:00","1986-06-12T00:00:00","1986-06-13T00:00:00","1986-06-16T00:00:00","1986-06-17T00:00:00","1986-06-18T00:00:00","1986-06-19T00:00:00","1986-06-20T00:00:00","1986-06-23T00:00:00","1986-06-24T00:00:00","1986-06-25T00:00:00","1986-06-26T00:00:00","1986-06-27T00:00:00","1986-06-30T00:00:00","1986-07-01T00:00:00","1986-07-02T00:00:00","1986-07-03T00:00:00","1986-07-04T00:00:00","1986-07-07T00:00:00","1986-07-08T00:00:00","1986-07-09T00:00:00","1986-07-10T00:00:00","1986-07-11T00:00:00","1986-07-14T00:00:00","1986-07-15T00:00:00","1986-07-16T00:00:00","1986-07-17T00:00:00","1986-07-18T00:00:00","1986-07-21T00:00:00","1986-07-22T00:00:00","1986-07-23T00:00:00","1986-07-24T00:00:00","1986-07-25T00:00:00","1986-07-28T00:00:00","1986-07-29T00:00:00","1986-07-30T00:00: ...

# %%
#getting the forecast result
forecast = result.forecast.df[["Date", "forecast"]]
forecast = forecast.rename(columns = {'forecast': 'silverkite'})
predictions_silverkite = forecast.iloc[-31:,:]
predictions_silverkite
# Out:
#            Date  silverkite
# 9951 2024-02-23   79.151947
# 9952 2024-02-26   80.006705
# 9953 2024-02-27   82.457695
# 9954 2024-02-28   82.457695
# 9955 2024-02-29   83.052287
# 9956 2024-03-01   83.052287
# 9957 2024-03-04   83.771292
# 9958 2024-03-05   83.771292
# 9959 2024-03-06   83.815195
# 9960 2024-03-07   84.018140
# 9961 2024-03-08   84.243781
# 9962 2024-03-11   84.575498
# 9963 2024-03-12   84.575498
# 9964 2024-03-13   84.575498
# 9965 2024-03-14   84.575498
# 9966 2024-03-15   84.575498
# 9967 2024-03-18   83.892490
# 9968 2024-03-19   83.560773
# 9969 2024-03-20   83.662615
# 9970 2024-03-21   83.436974
# 9971 2024-03-22   83.234029
# 9972 2024-03-25   83.559274
# 9973 2024-03-26   83.507652
# 9974 2024-03-27   83.507652
# 9975 2024-03-28   83.742217
# 9976 2024-03-29   83.742217
# 9977 2024-04-01   83.225081
# 9978 2024-04-02   83.428026
# 9979 2024-04-03   83.653668
# 9980 2024-04-04   83.653668
# 9981 2024-04-05   83.985384

# %%
#exporting
predictions_silverkite.to_csv("/content/drive/MyDrive/PCDS_OilPricePrediction/forecasting_products/predictions_silverkite_linearGrowth.csv")

# %% [markdown]
# ## Brent Data

# %% [markdown]
# ### 1) Silverkite Model

# %%
#Forecasting
forecaster_brent = Forecaster()
result_brent = forecaster_brent.run_forecast_config(df = eu_brent_fp,
                                        config = config_brent)
# Out:
# /usr/local/lib/python3.9/dist-packages/greykite/common/time_properties.py:197: UserWarning:
#
# Dropped 1 dates when filling gaps in input data. Provide data frequency and make sure data points are evenly spaced.
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 11 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 14 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 2 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 12 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 244 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 9 value(s) in y_true were NA or infinite and are omitted in error calc.
#
# /usr/local/lib/python3.9/dist-packages/greykite/common/evaluation.py:153: UserWarning:
#
# 253 value(s) in y_true were NA or infinite and are omitted in error calc.

# %%
#Look at the model summary
summary_brent = result_brent.model[-1].summary() #-1 restrieves the estimator from the pipeline
print(summary_brent)
# Out:
# ================================ Model Summary =================================
#
# Number of observations: 9334,   Number of features: 194
# Method: Gradient Boosting
# Number of Trees: 100,   Criterion: FRIEDMAN_MSE
# Subsample: 1.0,   Max features: 194,   Max depth: 3
#
# Residuals:
#          Min           1Q       Median           3Q          Max
#       -16.25       -1.566      -0.1381        1.346        21.12
#
#             Pred_col Feature importance  Importance rank
#            Intercept                 0.              194
#  events_C...New Year                 0.               81
#  events_C...w Year-1                 0.               80
#  events_C...w Year-2                 0.               79
#  events_C...w Year+1                 0.               78
#  events_C...w Year+2                 0.               77
# events_Christmas Day                 0.               76
#  events_C...as Day-1                 0.               75
#  events_C...as Day-2                 0.               74
#  events_C...as Day+1                 0.               73
#  events_C...as Day+2                 0.               72
#  events_E...Ireland]                 0.               71
#  events_E...eland]-1                 0.               70
#  events_E...eland]-2                 0.               69
#  events_E...eland]+1                 0.               68
#  events_E...eland]+2                 0.               67
#   events_Good Friday                 0.               66
# events_Good Friday-1                 0.               65
# events_Good Friday-2                 0.               64
# events_Good Friday+1                 0.               63
# events_Good Friday+2                 0.               82
#  events_I...ence Day                 0.               62
#  events_I...ce Day-1                 0.               83
#  events_I...ce Day-2                 0.               85
#  events_I...ce Day+1                 0.              104
#  events_I...ce Day+2                 0.              103
#     events_Labor Day                 0.              102
#   events_Labor Day-1                 0.              101
#   events_Labor Day-2                 0.              100
#   events_Labor Day+1                 0.               99
#   events_Labor Day+2                 0.               98
#  events_Memorial Day                 0.               97
#  events_M...al Day-1                 0.               96
#  events_M...al Day-2                 0.               95
#  events_M...al Day+1                 0.               94
#  events_M...al Day+2                 0.               93
# events_New Years Day                 0.               92
#  events_N...rs Day-1                 0.              105
#  events_N...rs Day-2                 0.               90
#  events_N...rs Day+1                 0.               89
#  events_N...rs Day+2                 0.               88
#         events_Other                 0.               87
#       events_Other-1                 0.               86
#       events_Other-2                 0.               84
#       events_Other+1                 0.               61
#       events_Other+2                 0.               50
#  events_Thanksgiving                 0.               59
#  events_T...giving-1                 0.               38
#  events_T...giving-2                 0.               37
#  events_T...giving+1                 0.               36
#  events_T...giving+2                 0.               35
#  events_Veterans Day                 0.               34
#  events_V...ns Day-1                 0.               33
#  events_V...ns Day-2                 0.               32
#  events_V...ns Day+1                 0.               31
#  events_V...ns Day+2                 0.               24
#        str_dow_2-Tue                 0.               28
#        str_dow_3-Wed                 0.               25
#        str_dow_4-Thu                 0.               23
#        str_dow_5-Fri                 0.               22
#        str_dow_6-Sat                 0.               26
#        str_dow_7-Sun                 0.               27
#                  ct1             0.3415                1
#       is_weekend:ct1                 0.               29
#    str_dow_2-Tue:ct1                 0.               39
#    str_dow_3-Wed:ct1                 0.               41
#    str_dow_4-Thu:ct1                 0.               51
#    str_dow_5-Fri:ct1                 0.               58
#    str_dow_6-Sat:ct1                 0.               40
#    str_dow_7-Sun:ct1                 0.               55
#    cp0_1996_12_11_00             0.2129                3
#  is_weeke...12_11_00                 0.               53
#  str_dow_...12_11_00                 0.               52
#  str_dow_...12_11_00                 0.               42
#  str_dow_...12_11_00                 0.               49
#  str_dow_...12_11_00                 0.               47
#  str_dow_...12_11_00                 0.               46
#  str_dow_...12_11_00                 0.               45
#    cp1_2002_12_19_00             0.2932                2
#  is_weeke...12_19_00                 0.               43
#  str_dow_...12_19_00                 0.               56
#  str_dow_...12_19_00                 0.               30
#  str_dow_...12_19_00                 0.               44
#  str_dow_...12_19_00                 0.               48
#  str_dow_...12_19_00                 0.               54
#  str_dow_...12_19_00                 0.               57
#    cp2_2008_12_26_00            0.05933                4
#  is_weeke...12_26_00                 0.               91
#  str_dow_...12_26_00                 0.              107
#  str_dow_...12_26_00                 0.              108
#  str_dow_...12_26_00                 0.              171
#  str_dow_...12_26_00                 0.              170
#  str_dow_...12_26_00                 0.              169
#  str_dow_...12_26_00                 0.              168
#    cp3_2012_03_06_00             0.0392                5
#  is_weeke...03_06_00                 0.              167
#  str_dow_...03_06_00                 0.              106
#  str_dow_...03_06_00                 0.              165
#  str_dow_...03_06_00                 0.              164
#  str_dow_...03_06_00                 0.              162
#  str_dow_...03_06_00                 0.              153
#  str_dow_...03_06_00                 0.              161
#    cp4_2012_07_12_00            0.01998                7
#  is_weeke...07_12_00                 0.              160
#  str_dow_...07_12_00                 0.              159
#  str_dow_...07_12_00                 0.              158
#  str_dow_...07_12_00                 0.              157
#  str_dow_...07_12_00                 0.              156
#  str_dow_...07_12_00                 0.              155
#  str_dow_...07_12_00                 0.              154
#    cp5_2020_04_28_00            0.02734                6
#  is_weeke...04_28_00                 0.              172
#  str_dow_...04_28_00                 0.              163
#  str_dow_...04_28_00                 0.              173
#  str_dow_...04_28_00                 0.              185
#  str_dow_...04_28_00                 0.              193
#  str_dow_...04_28_00                 0.              192
#  str_dow_...04_28_00                 0.              191
#  ct1:sin1_tow_weekly                 0.              190
#  ct1:cos1_tow_weekly                 0.              189
#  ct1:sin2_tow_weekly                 0.              188
#  ct1:cos2_tow_weekly                 0.              187
#  cp0_1996...w_weekly                 0.              186
#  cp0_1996...w_weekly                 0.              184
#  cp0_1996...w_weekly                 0.              175
#  cp0_1996...w_weekly                 0.              183
#  cp1_2002...w_weekly                 0.              182
#  cp1_2002...w_weekly                 0.              181
#  cp1_2002...w_weekly                 0.              180
#  cp1_2002...w_weekly                 0.              179
#  cp2_2008...w_weekly                 0.              178
#  cp2_2008...w_weekly                 0.              177
#  cp2_2008...w_weekly                 0.              176
#  cp2_2008...w_weekly                 0.              174
#  cp3_2012...w_weekly                 0.              152
#  cp3_2012...w_weekly                 0.              151
#  cp3_2012...w_weekly                 0.              150
#  cp3_2012...w_weekly                 0.              127
#  cp4_2012...w_weekly                 0.              126
#  cp4_2012...w_weekly                 0.              125
#  cp4_2012...w_weekly                 0.              124
#  cp4_2012...w_weekly                 0.              123
#  cp5_2020...w_weekly                 0.              122
#  cp5_2020...w_weekly                 0.              121
#  cp5_2020...w_weekly                 0.              120
#  cp5_2020...w_weekly                 0.              119
#      sin1_tow_weekly                 0.              118
#      cos1_tow_weekly                 0.              117
#      sin2_tow_weekly                 0.              116
#      cos2_tow_weekly                 0.              115
#      sin3_tow_weekly                 0.              114
#      cos3_tow_weekly                 0.              113
#      sin4_tow_weekly                 0.              112
#      cos4_tow_weekly                 0.              111
#   sin1_toq_quarterly          4.984e-05               13
#   cos1_toq_quarterly                 0.              110
#   sin2_toq_quarterly                 0.              109
#   cos2_toq_quarterly                 0.              128
#   sin3_toq_quarterly                 0.              129
#   cos3_toq_quarterly                 0.              130
#   sin4_toq_quarterly                 0.              141
#   cos4_toq_quarterly                 0.              149
#   sin5_toq_quarterly                 0.              148
#   cos5_toq_quarterly                 0.              147
#      sin1_ct1_yearly          0.0004937                9
#      cos1_ct1_yearly             0.0052                8
#      sin2_ct1_yearly          0.0002925               10
#      cos2_ct1_yearly                 0.              146
#      sin3_ct1_yearly          0.0002262               12
#      cos3_ct1_yearly          3.971e-05               14
#      sin4_ct1_yearly          0.0002283               11
#      cos4_ct1_yearly                 0.              145
#      sin5_ct1_yearly          1.562e-05               15
#      cos5_ct1_yearly          2.039e-06               20
#      sin6_ct1_yearly          6.888e-06               17
#      cos6_ct1_yearly                 0.              144
#      sin7_ct1_yearly                 0.              143
#      cos7_ct1_yearly          2.885e-07               21
#      sin8_ct1_yearly          4.032e-06               18
#      cos8_ct1_yearly                 0.              142
#      sin9_ct1_yearly                 0.              140
#      cos9_ct1_yearly                 0.              131
#     sin10_ct1_yearly                 0.              139
#     cos10_ct1_yearly                 0.              138
#     sin11_ct1_yearly                 0.              137
#     cos11_ct1_yearly                 0.              136
#     sin12_ct1_yearly                 0.              135
#     cos12_ct1_yearly                 0.              134
#     sin13_ct1_yearly          3.709e-06               19
#     cos13_ct1_yearly                 0.              133
#     sin14_ct1_yearly                 0.              132
#     cos14_ct1_yearly          7.696e-06               16
#     sin15_ct1_yearly                 0.              166
#     cos15_ct1_yearly                 0.               60
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names

# %%
#visualization
fig_brent = result_brent.forecast_brent.plot_components()
iplot(fig_brent)

# %%
#visualization
fig1_brent = result_brent.backtest.plot()
iplot(fig1_brent)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="489f721f-b1cf-423f-9373-3c900e7a8bc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("489f721f-b1cf-423f-9373-3c900e7a8bc2")) {                    Plotly.newPlot(                        "489f721f-b1cf-423f-9373-3c900e7a8bc2",                        [{"line":{"color":"rgba(250, 43, 20, 0.7)"},"marker":{"color":"rgba(250, 43, 20, 0.7)","size":2.0},"mode":"lines+markers","name":"Actual","opacity":1.0,"x":["1987-05-20T00:00:00","1987-05-21T00:00:00","1987-05-22T00:00:00","1987-05-25T00:00:00","1987-05-26T00:00:00","1987-05-27T00:00:00","1987-05-28T00:00:00","1987-05-29T00:00:00","1987-06-01T00:00:00","1987-06-02T00:00:00","1987-06-03T00:00:00","1987-06-04T00:00:00","1987-06-05T00:00:00","1987-06-08T00:00:00","1987-06-09T00:00:00","1987-06-10T00:00:00","1987-06-11T00:00:00","1987-06-12T00:00:00","1987-06-15T00:00:00","1987-06-16T00:00:00","1987-06-17T00:00:00","1987-06-18T00:00:00","1987-06-19T00:00:00","1987-06-22T00:00:00","1987-06-23T00:00:00","1987-06-24T00:00:00","1987-06-25T00:00:00","1987-06-26T00:00:00","1987-06-29T00:00:00","1987-06-30T00:00:00","1987-07-01T00:00:00","1987-07-02T00:00:00","1987-07-03T00:00:00","1987-07-06T00:00:00","1987-07-07T00:00:00","1987-07-08T00:00:00","1987-07-09T00:00:00","1987-07-10T00:00:00","1987-07-13T00:00:00","1987-07-14T00:00:00","1987-07-15T00:00:00","1987-07-16T00:00:00","1987-07-17T00:00:00","1987-07-20T00:00:00","1987-07-21T00:00:00","1987-07-22T00:00:00","1987-07-23T00:00:00","1987-07-24T00:00:00","1987-07-27T00:00:00","1987-07-28T00:00:00","1987-07-29T00:00:00","1987-07-30T00:00:00","1987-07-31T00:00:00","1987-08-03T00:00:00","1987-08-04T00:00:00","1987-08-05T00:00:00","1987-08-06T00:00:00","1987-08-07T00:00:00","1987-08-10T00:00:00","1987-08-11T00:00:00","1987-08-12T00:00:00","1987-08-13T00:00:00","1987-08-14T00:00:00","1987-08-17T00:00:00","1987-08-18T00:00:00","1987-08-19T00:00:00","1987-08-20T00:00:00","1987-08-21T00:00:00","1987-08-24T00:00:00","1987-08-25T00:00:00","1987-08-26T00:00:00","1987-08-27T00:00:00","1987-08-28T00:00:00","1987-08-31T00:00:00","1987-09-01T00:00:00","1987-09-02T00:00:00","1987-09-03T00:00:00","1987-09-04T00:00:00","1987-09-07T00:00:00","1987-09-08T00:00:00","1987-09-09T00:00:00","1987-09-10T00:00:00","1987-09-11T00:00:00","1987-09-14T00:00:00","1987-09-15T00:00:00","1987-09-16T00:00:00","1987-09-17T00:00:00","1987-09-18T00:00:00","1987-09-21T00:00:00","1987-09-22T00:00:00","1987-09-23T00:00:00","1987-09-24T00:00:00","1987-09-25T00:00:00","1987-09-28T00:00:00","1987-09-29T00:00:00","1987-09-30T00:00:00","1987-10-01T00:00:00","1987-10-02T00:00:00","1987-10-05T00:00:00","1987-10-06T00:00:00","1987-10-07T00:00:00","1987-10-08T00:00:00","1987-10-09T00:00:00","1987-10-12T00:00:00","1987-10-13T00:00:00","1987-10-14T00:00:00","1987-10-15T00:00:00","1987-10-16T00:00:00","1987-10-19T00:00:00","1987-10-20T00:00:00","1987-10-21T00:00:00","1987-10-22T00:00:00","1987-10-23T00:00:00","1987-10-26T00:00:00","1987-10-27T00:00:00","1987-10-28T00:00:00","1987-10-29T00:00:00","1987-10-30T00:00:00","1987-11-02T00:00:00","1987-11-03T00:00:00","1987-11-04T00:00:00","1987-11-05T00:00:00","1987-11-06T00:00:00","1987-11-09T00:00:00","1987-11-10T00:00:00","1987-11-11T00:00:00","1987-11-12T00:00:00","1987-11-13T00:00:00","1987-11-16T00:00:00","1987-11-17T00:00:00","1987-11-18T00:00:00","1987-11-19T00:00:00","1987-11-20T00:00:00","1987-11-23T00:00:00","1987-11-24T00:00:00","1987-11-25T00:00:00","1987-11-26T00:00:00","1987-11-27T00:00:00","1987-11-30T00:00:00","1987-12-01T00:00:00","1987-12-02T00:00:00","1987-12-03T00:00:00","1987-12-04T00:00:00","1987-12-07T00:00:00","1987-12-08T00:00:00","1987-12-09T00:00:00","1987-12-10T00:00:00","1987-12-11T00:00:00","1987-12-14T00:00:00","1987-12-15T00:00: ...

# %%
#getting the forecast result
forecast_brent = result_brent.forecast.df[["Date", "forecast"]]
forecast_brent = forecast_brent.rename(columns = {'forecast': 'silverkite'})
predictions_brent_silverkite = forecast_brent.iloc[-31:,:]
predictions_brent_silverkite
# Out:
#            Date  silverkite
# 9592 2024-02-23   85.401179
# 9593 2024-02-26   88.645569
# 9594 2024-02-27   88.767571
# 9595 2024-02-28   95.691714
# 9596 2024-02-29  102.735063
# 9597 2024-03-01  104.343618
# 9598 2024-03-04  104.760966
# 9599 2024-03-05  104.760966
# 9600 2024-03-06  106.997284
# 9601 2024-03-07  106.997284
# 9602 2024-03-08  106.997284
# 9603 2024-03-11  106.566728
# 9604 2024-03-12  105.864027
# 9605 2024-03-13  105.864027
# 9606 2024-03-14  105.851303
# 9607 2024-03-15  105.851303
# 9608 2024-03-18  106.499681
# 9609 2024-03-19  106.499681
# 9610 2024-03-20  106.499681
# 9611 2024-03-21  105.989898
# 9612 2024-03-22  105.989898
# 9613 2024-03-25  104.916584
# 9614 2024-03-26  104.916584
# 9615 2024-03-27  105.003485
# 9616 2024-03-28  105.305579
# 9617 2024-03-29  104.501148
# 9618 2024-04-01  101.504797
# 9619 2024-04-02  101.259771
# 9620 2024-04-03  102.008060
# 9621 2024-04-04   99.405164
# 9622 2024-04-05   99.914946

# %%
#exporting
predictions_brent_silverkite.to_csv("/content/drive/MyDrive/PCDS_OilPricePrediction/forecasting_products/predictions_brent_silverkite_linearGrowth.csv")

# %% [markdown]
# # 3_Parameter Tuning results

# %% [markdown]
# ## Cushing Data

# %% [markdown]
# ### 1) Silverkite Model

# %%
#CV results
cv_results = summarize_grid_search_results(
    grid_search = result.grid_search,
    decimals = 1,
    score_func = EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
#Set the CV results index
cv_results["params"] = cv_results["params"].astype(str)
cv_results.set_index("params", drop = True, inplace = True)
cv_results
# Out:
#                                                     rank_test_CORR  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
#
#                                                     rank_test_R2  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...             1
# [('estimator__fit_algorithm_dict', {'fit_algori...             2
#
#                                                     rank_test_MSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...              1
# [('estimator__fit_algorithm_dict', {'fit_algori...              2
#
#                                                     rank_test_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
#
#                                                     rank_test_MAE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...              1
# [('estimator__fit_algorithm_dict', {'fit_algori...              2
#
#                                                     rank_test_MedAE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                1
# [('estimator__fit_algorithm_dict', {'fit_algori...                2
#
#                                                     rank_test_MAPE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
#
#                                                     rank_test_MedAPE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                 1
# [('estimator__fit_algorithm_dict', {'fit_algori...                 2
#
#                                                     rank_test_sMAPE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                1
# [('estimator__fit_algorithm_dict', {'fit_algori...                2
#
#                                                     rank_test_Q80  ...  \
# params                                                             ...
# [('estimator__fit_algorithm_dict', {'fit_algori...              1  ...
# [('estimator__fit_algorithm_dict', {'fit_algori...              2  ...
#
#                                                     split2_train_OutsideTolerance4p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.1
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.7
#
#                                                     std_train_OutsideTolerance4p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.1
#
#                                                     split0_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.3
# [('estimator__fit_algorithm_dict', {'fit_algori...                             1.0
#
#                                                     split1_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.8
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.8
#
#                                                     split2_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.6
# [('estimator__fit_algorithm_dict', {'fit_algori...                             1.0
#
#                                                     std_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                          0.2
# [('estimator__fit_algorithm_dict', {'fit_algori...                          0.1
#
#                                                     split0_train_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.7
#
#                                                     split1_train_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.5
#
#                                                     split2_train_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.6
#
#                                                     std_train_OutsideTolerance5p
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.1
#
# [2 rows x 263 columns]

# %%
#Looking at the best results
cv_results[["rank_test_RMSE", "mean_test_RMSE","mean_test_MSE","mean_train_RMSE","mean_train_MSE",
            "param_estimator__fit_algorithm_dict",
            "param_estimator__growth_term"]]
# Out:
#                                                     rank_test_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
#
#                                                     mean_test_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...             5.3
# [('estimator__fit_algorithm_dict', {'fit_algori...             8.2
#
#                                                     mean_test_MSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...           36.2
# [('estimator__fit_algorithm_dict', {'fit_algori...           77.3
#
#                                                     mean_train_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...              0.6
# [('estimator__fit_algorithm_dict', {'fit_algori...              4.1
#
#                                                     mean_train_MSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...             0.4
# [('estimator__fit_algorithm_dict', {'fit_algori...            19.7
#
#                                                        param_estimator__fit_algorithm_dict  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...  {'fit_algorithm': 'gradient_boosting'}
# [('estimator__fit_algorithm_dict', {'fit_algori...              {'fit_algorithm': 'ridge'}
#
#                                                    param_estimator__growth_term
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                       linear
# [('estimator__fit_algorithm_dict', {'fit_algori...                       linear

# %%
best_params = cv_results[cv_results.rank_test_RMSE == 1][["mean_test_RMSE",
                                            "param_estimator__fit_algorithm_dict",
                                            "param_estimator__growth_term"]].transpose()

# %%
best_params.to_csv("/content/drive/MyDrive/PCDS_OilPricePrediction/forecasting_products/best_params_silverkite_linearGrowth.csv")

# %% [markdown]
# ## Brent Data

# %% [markdown]
# ### 1) Silverkite Model

# %%
#CV results
cv_results_brent = summarize_grid_search_results(
    grid_search = result_brent.grid_search,
    decimals = 1,
    score_func = EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
#Set the CV results index
cv_results_brent["params"] = cv_results_brent["params"].astype(str)
cv_results_brent.set_index("params", drop = True, inplace = True)
cv_results_brent
# Out:
#                                                     rank_test_CORR  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
#
#                                                     rank_test_R2  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...             1
# [('estimator__fit_algorithm_dict', {'fit_algori...             2
#
#                                                     rank_test_MSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...              1
# [('estimator__fit_algorithm_dict', {'fit_algori...              2
#
#                                                     rank_test_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
#
#                                                     rank_test_MAE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...              1
# [('estimator__fit_algorithm_dict', {'fit_algori...              2
#
#                                                     rank_test_MedAE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                1
# [('estimator__fit_algorithm_dict', {'fit_algori...                2
#
#                                                     rank_test_MAPE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
#
#                                                     rank_test_MedAPE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                 1
# [('estimator__fit_algorithm_dict', {'fit_algori...                 2
#
#                                                     rank_test_sMAPE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                1
# [('estimator__fit_algorithm_dict', {'fit_algori...                2
#
#                                                     rank_test_Q80  ...  \
# params                                                             ...
# [('estimator__fit_algorithm_dict', {'fit_algori...              1  ...
# [('estimator__fit_algorithm_dict', {'fit_algori...              2  ...
#
#                                                     split2_train_OutsideTolerance4p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.7
#
#                                                     std_train_OutsideTolerance4p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.1
#
#                                                     split0_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.6
# [('estimator__fit_algorithm_dict', {'fit_algori...                             1.0
#
#                                                     split1_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.7
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.7
#
#                                                     split2_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                             0.4
# [('estimator__fit_algorithm_dict', {'fit_algori...                             1.0
#
#                                                     std_test_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                          0.2
# [('estimator__fit_algorithm_dict', {'fit_algori...                          0.1
#
#                                                     split0_train_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.7
#
#                                                     split1_train_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.5
#
#                                                     split2_train_OutsideTolerance5p  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                              0.7
#
#                                                     std_train_OutsideTolerance5p
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.0
# [('estimator__fit_algorithm_dict', {'fit_algori...                           0.1
#
# [2 rows x 263 columns]

# %%
#Looking at the best results
cv_results_brent[["rank_test_RMSE", "mean_test_RMSE","mean_test_MSE","mean_train_RMSE","mean_train_MSE",
            "param_estimator__fit_algorithm_dict",
            "param_estimator__growth_term"]]
# Out:
#                                                     rank_test_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...               1
# [('estimator__fit_algorithm_dict', {'fit_algori...               2
#
#                                                     mean_test_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...             5.5
# [('estimator__fit_algorithm_dict', {'fit_algori...            10.4
#
#                                                     mean_test_MSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...           31.9
# [('estimator__fit_algorithm_dict', {'fit_algori...          108.3
#
#                                                     mean_train_RMSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...              0.5
# [('estimator__fit_algorithm_dict', {'fit_algori...              4.1
#
#                                                     mean_train_MSE  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...             0.3
# [('estimator__fit_algorithm_dict', {'fit_algori...            20.2
#
#                                                        param_estimator__fit_algorithm_dict  \
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...  {'fit_algorithm': 'gradient_boosting'}
# [('estimator__fit_algorithm_dict', {'fit_algori...              {'fit_algorithm': 'ridge'}
#
#                                                    param_estimator__growth_term
# params
# [('estimator__fit_algorithm_dict', {'fit_algori...                       linear
# [('estimator__fit_algorithm_dict', {'fit_algori...                       linear

# %%
best_params_brent = cv_results_brent[cv_results_brent.rank_test_RMSE == 1][["mean_test_RMSE",
                                            "param_estimator__fit_algorithm_dict",
                                            "param_estimator__growth_term"]].transpose()

# %%
best_params_brent.to_csv("/content/drive/MyDrive/PCDS_OilPricePrediction/forecasting_products/best_params_brent_silverkite_linearGrowth.csv")

# %% [markdown]
# # Results

# %% [markdown]
# Hence after the testing we find that the built with gradient boosting algorithm perfomrs better in predicting the future values of crude oil prices and hence we proceed with that modelfor future uses and for presentation purposes.
#
# Also, It is to be notes that CV plots generated during the model building phase contains data from the test data too that gets evalueated separately to avoid any data leakage.
#
# •The model was tested using two fit algotrithm ridge regression and gradient boosting and gradient boosting yielded much lesser error. The results of the better model with the gradient boosting fit algorithm is presented here.
#
# •Although, the test period has been modified in LinkedIN silverkite The MSE and RMSE of the forecast period was evaluated to be  31.9 & 5.5 and 36.2 & 5.3 for EU Brent and US Cushing Respectively.
